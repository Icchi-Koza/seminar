# %%
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: outcome in c:\users\ichirokozakai\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# ...
#
# ...
# WARNING: You are using pip version 22.0.2; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\IchiroKozakai\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.2; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\IchiroKozakai\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
import time
import pandas as pd

# %%
browser=webdriver.Chrome(executable_path='C:\\Users\\IchiroKozakai\\vscode for seminar\\Chromedriver.exe')
browser.implicitly_wait(0.3)
# Out:
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\4241346361.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser=webdriver.Chrome(executable_path='C:\\Users\\IchiroKozakai\\vscode for seminar\\Chromedriver.exe')

# %%
url="https://auth.lib.keio.ac.jp/db/?key=edu21"
browser.get(url)
time.sleep(1)
print('complete')
# Out:
# complete

# %%
button=browser.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div/div[2]/div/form/input[1]')
button.click()
print('completed')
# Out:
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\2569254230.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=browser.find_element_by_xpath('/html/body/div/div/div[2]/div/div/div/div[2]/div/form/input[1]')
# completed

# %%
button2=browser.find_element_by_name('keiojpuser')
button2.clear()
button2.send_keys('ichirokozakai@keio.jp')
button3=browser.find_element_by_name('keiojppassword')
button3.clear()
button3.send_keys('Ichiro1600')
fullxpass='/html/body/div[1]/div[3]/div/form/table/tbody/tr[3]/td[2]/input[1]'
button4=browser.find_element_by_xpath(fullxpass)
button4.click()
# Out:
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\1090634391.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button2=browser.find_element_by_name('keiojpuser')
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\1090634391.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button3=browser.find_element_by_name('keiojppassword')
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\1090634391.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button4=browser.find_element_by_xpath(fullxpass)

# %%
pass2='/html/body/div/div/form/input[1]'
button5=browser.find_element_by_xpath(pass2)
button5.click()
# Out:
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\1138454768.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button5=browser.find_element_by_xpath(pass2)

# %%
pass3='/html/body/div/div[2]/div/section[2]/div/dl/span/span[1]/a'
button6=browser.find_element_by_xpath(pass3)
button6.click()
time.sleep(3)
# Out:
# C:\Users\IchiroKozakai\AppData\Local\Temp\ipykernel_9044\3936920677.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button6=browser.find_element_by_xpath(pass3)
