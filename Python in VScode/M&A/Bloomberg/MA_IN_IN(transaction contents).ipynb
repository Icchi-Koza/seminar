# %%
import datetime as dt
import japanize_matplotlib
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.reset_option('display.float_format')

# %%
import chardet
with open('MA_IN_IN(TransactionContents).txt','rb') as f:
    b=f.read()
chardet.detect(b)
# Out:
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}

# %%
dat1=pd.read_table('MA_IN_IN(TransactionContents).txt',encoding='UTF-16')
TransactionAttributes=dat1.drop('Unnamed: 0',axis=1)

# %%
MAinfo1=TransactionAttributes.head(15)
MAinfo2=TransactionAttributes[15:47]
MAinfo3=TransactionAttributes[47:55]
MAinfo4=TransactionAttributes[55:61]
MAinfo5=TransactionAttributes[61:68]
MAinfo6=TransactionAttributes[68:74]
MAinfo7=TransactionAttributes[74:86]
MAinfo8=TransactionAttributes[86:98]
MAinfo9=TransactionAttributes[98:104]
MAinfo10=TransactionAttributes[104:115]
MAinfo11=TransactionAttributes[115:121]
MAinfo12=TransactionAttributes[121:]

# %%
MAinfo1=MAinfo1.rename(columns={'取引属性':'tgt mult info','Unnamed: 2':'No. of Tx','Unnamed: 3':'min-max','Unnamed: 4':'median'}).drop(0,axis=0).reset_index(drop=True)
MAinfo2=MAinfo2.rename(columns={'取引属性':'Tx type','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(15,axis=0).reset_index(drop=True)
MAinfo3=MAinfo3.rename(columns={'取引属性':'Payment details','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(47,axis=0).reset_index(drop=True)
MAinfo4=MAinfo4.rename(columns={'取引属性':'Desc of Tx amount','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(55,axis=0).reset_index(drop=True)
MAinfo5=MAinfo5.rename(columns={'取引属性':'Acquisition type','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(61,axis=0).reset_index(drop=True)
MAinfo6=MAinfo6.rename(columns={'取引属性':'Tx situation','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(68,axis=0).reset_index(drop=True)
MAinfo7=MAinfo7.rename(columns={'取引属性':'Goodwill amortization','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(74,axis=0).reset_index(drop=True)
MAinfo8=MAinfo8.rename(columns={'取引属性':'Current goodwill amortization','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(86,axis=0).reset_index(drop=True)
MAinfo9=MAinfo9.rename(columns={'取引属性':"Acquiring companies' location",'Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(98,axis=0).reset_index(drop=True)
MAinfo10=MAinfo10.rename(columns={'取引属性':'IND of acquiring companies','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(104,axis=0).reset_index(drop=True)
MAinfo11=MAinfo11.rename(columns={'取引属性':"TGT companies' location",'Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(115,axis=0).reset_index(drop=True)
MAinfo12=MAinfo12.rename(columns={'取引属性':'IND of tgt companies','Unnamed: 2':'No. of Tx','Unnamed: 3':'Total value','Unnamed: 4':'%'}).drop(121,axis=0).reset_index(drop=True)

# %%
MAinfo2
# Out:
#               Tx type No. of Tx Total value      %
# 0                企業買収      4913          1T  61.69
# 1             株式の追加取得      2462     404.23B  24.91
# 2                資産売却      5289     338.94B  20.89
# 3           過半数株主持分取得      1995      282.9B  17.43
# 4               国際間取引       565     246.35B  15.18
# 5               公開買付け       720      229.6B  14.15
# 6       ﾌﾟﾗｲﾍﾞｰﾄｴｸｲﾃｨ       397     152.65B   9.41
# 7            PEﾊﾞｲｱｳﾄ        77      87.25B   5.38
# 8           ｽｸｲｰｽﾞｱｳﾄ       205      49.87B   3.07
# 9               第3者割当       270      47.89B   2.95
# 10              PE売り手       137       38.9B    2.4
# 11     ﾏﾈｼﾞﾒﾝﾄ･ﾊﾞｲｱｳﾄ       236      33.43B   2.06
# 12            公益事業民営化         4      25.56B   1.58
# 13              破産･清算        98      12.04B   0.74
# 14               転換株式        21      10.22B   0.63
# 15               逆さ合併         4       8.76B   0.54
# 16               競争買付         4       8.43B   0.52
# ...
